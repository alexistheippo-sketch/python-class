# %% [markdown]
# <a href="https://colab.research.google.com/github/alexistheippo-sketch/python-class/blob/main/AlexisSanchezModuleThreeLessonOneActivity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Alexis Sanchez - 7/8/2026
# I learned how to define my own functions with def, how to call them with arguments, and when to use one-line vs multi-line docstrings.
# I had trouble when I put input() inside my function and when I forgot to print, so I fixed it by moving input outside the function and adding a print statement.

# %% [markdown]
# # Module Three Lesson One Activity
# ## Simple Functions
# - **Creating a simple function with a parameter**
# - **Documenting a simple function with a parameter**
# - Exploring functions with `return` values
# - Creating functions with multiple parameters
# - Sequence in Python
#
# -----
#
# ### Student will be able to
# - **Create functions with a parameter**
# - **Document functions with docstrings**
# - Create functions with a `return` value
# - Create functions with multiple parameters
# - Use knowledge of sequence in coding tasks
# - Use coding best practices
#
# #### **Before submission**: Remember for max credit, you need to add a complete header comment in a code cell at the very top of this file and descriptive comments in each code cell below (examples AND tasks) that explains what your code is doing.
#
# #### **ALL** functions need a formatted docstring – see the bottom of Mod 3 Lesson 1 Activity for the requirements.

# %% [markdown]
# ## Concept: Functions with Arguments
# Functions are used for code tasks that are intended to be reused.
#
# [View Functions with Arguments video](https://ncvps.yuja.com/V/Video?v=4514284&node=15054054&a=1683166288&autoplay=1)
#
# Python allows us to create **User Defined Functions** and provides many **Built-in Functions** such as **`print()`**.
# - **`print()`** can be called using arguments (or without) and sends text to standard output, such as the console.
# - **`print()`** uses **Parameters** to define the variable Arguments that can be passed to the Function.
# - **`print()`** defines multiple string/numbers parameters which means we can send a long list of Arguments to **`print()`**, separated by commas.
# - **`print()`** can also be called directly with just its name and empty parenthesis and it will return a blank line to standard output.

# %% [markdown]
# ### Examples

# %%
# This prints a greeting by sending two string arguments to the print() function
print('Hello World!', 'I am sending string arguments to print ')
# Out:
# Hello World! I am sending string arguments to print

# %%
#  This stores a student's age and name in variables, then prints them in a sentenc
student_age = 17
student_name = "Hiroto Yamaguchi"
print(student_name,'will be in the class for',student_age, 'year old students.')
# Out:
# Hiroto Yamaguchi will be in the class for 17 year old students.

# %%
# This prints several lines of text and uses an empty print() to make a blank line
print("line 1")
print("line 2")
# line 3 is an empty return - the default when no arguments
print()
print("line 4")
# Out:
# line 1
# line 2
#
# line 4

# %% [markdown]
# ## Task 1: Passing arguments to `print()`
# ### Many arguments can be passed to print
#
# - Update the print statement to use **`print()`** with **8** or more arguments

# %%
#[ ] increase the number of arguments used in print() to 8 or more
# This stores a student's name and age, then prints them using 8+ arguments
student_age = 17
student_name = "Hiroto Yamaguchi"
print('Student', student_name, 'is', student_age, 'years old, so', student_name, 'will be in the class for', student_age, 'year old students.')
# Out:
# Student Hiroto Yamaguchi is 17 years old, so Hiroto Yamaguchi will be in the class for 17 year old students.

# %% [markdown]
# # &nbsp;
# <font size="6" color="#00A0B2"  face="verdana"> <B></B></font>
# ## Concept: Simple Functions
# Creating user-defined functions is at the core of computer programming.  Functions enable code reuse and make code easier to develop and maintain.
#
# [View Simple Functions video](https://ncvps.yuja.com/V/Video?v=4514289&node=15054058&a=538910260&autoplay=1)
# ### Basics of a user-defined function
# - Define a function with **`def`**
# - Use indentation (4 spaces)
# - Define parameters
# - Optional parameters
# - **`return`** values (or none)
# - Function scope (basics defaults)

# %% [markdown]
# ### `def some_function():`
# Use the &nbsp;**`def`** &nbsp;statement when creating a **function**.
# - Use a function name that **starts with a letter** or underscore (usually a lowercase letter).
# - Function names can contain **letters, numbers or underscores**.
# - Parentheses &nbsp; **()**  &nbsp; follow the function name.
# - A colon &nbsp; **:**  &nbsp; follows the parenthesis.
# - The code for the function is indented under the function definition (use 4 spaces for this course).
#
# ```python
# def some_function():
#    #code the function tasks indented here
# ```
# The **end of the function** is denoted by returning to **no indentation**.

# %% [markdown]
# ### Examples

# %%
# defines a function named say_hi
# This cell defines a function named say_hi that prints a greeting and a goodbye
def say_hi():
    """Print a greeting and a goodbye message."""
    print("Hello there!")
    print("goodbye")

# %%
# define three_three
# This cell defines a function named three_three that prints the number 33
def three_three():
    """Print the number 33."""
    print(33)

# %% [markdown]
# ## Concept: Calling Functions
# Call a simple function using the function name followed by parentheses.  For instance, calling print is
# **`print()`**

# %% [markdown]
# ### Examples

# %%
# This cell defines the say_hi and three_three functions, then calls them both
# [ ] review and run the code

def say_hi():
    """Print a greeting and a goodbye message."""
    print("Hello there!")
    print("goodbye")
# end of indentation ends the function

# define three_three
def three_three():
    """Print the number 33."""
    print(33)

# calling the functions
say_hi()
print()
three_three()
# Out:
# Hello there!
# goodbye
#
# 33

# %% [markdown]
# ## Task 2: Define and call a simple function `yell_it()`
# ### `yell_it()` &nbsp; prints the phrase with "!" concatenated to the end
# - Takes no arguments
# - Indented function code does the following
#   - Define a variable for called **`phrase`** and intialize with a short *phrase*
#   - Prints **`phrase`** as all upper-case letters followed by "!"
# - Call &nbsp; `yell_it` &nbsp; at the bottom of the cell after the function &nbsp;**`def`**.&nbsp; (**Tip:** no indentation should be used.)
# - As this is a simple function with no arguments or return values - a one-line docstring should be added in the appropriate location in the function

# %%
# This cell defines a function named yell_it that prints a phrase in caps with "!", then calls it
def yell_it():
    """Print the phrase in upper-case letters followed by an exclamation point."""
    phrase = "Hello how are you"
    print(phrase.upper() + "!")

yell_it()
# Out:
# HELLO HOW ARE YOU!

# %% [markdown]
# ## Concept: Function Parameters
# [View Function Parameters video](https://ncvps.yuja.com/V/Video?v=4514279&node=15054048&a=388225125&autoplay=1)
#
# **`print()`** and **`type()`** are examples of built-in functions that have **parameters** defined.
#
# **`type()`** has a parameter for a **Python Object** and sends back the *type* of the object.
#
# An **Argument** is a value given for a parameter when calling a function.
# - **`type`** is called providing an **Argument** - in this case the string *"Hello"*
# ```python
# type("Hello")
# ```
#
# ### Defining function parameters
# - Parameters are defined inside of the parentheses as part of a function **`def`** statement
# - Parameters are typically copies of objects that are available for use in function code
# ```python
# def say_this(phrase):
#       print(phrase)
# ```
# ### Functions can have default arguments
# - Default arguments are used if no argument is supplied
# - Default arguments are assigned when creating the parameter list
# ```python
# def say_this(phrase = "Hi"):
#       print(phrase)
# ```
# ## Documentation requirements for functions with parameters
# -Docstrings work great as a multiline header comment.
# -Multi-line docstrings for functions are more elaborate and start with a summary line written as a command ending with a period.
# -The summary line is followed by a blank line and then descriptions of the parameters(arguments), exceptions raised, if any, and the return value(s).
# -Multi-line docstrings end with triple quotes and a blank line.
# -Docstrings are indented under the function def line

# %% [markdown]
# ### Example

# %%
# title_this() uses .title() to change the user input into title case.
# This  defines title_this(), which changes user input to title case, then calls it and prints the result
def title_this(phrase):
    """
    Change the title entered to title case

    args:
      phrase_to_title: string to be changed to title case
    returns:
      titled_phrase: string after it has been changed to title case
    """
    titled_phrase = phrase.title()
    return titled_phrase
# get input
phrase_to_title =input("Please enter a phrase to title: ")
# call function with a string, print return value
print(title_this(phrase_to_title))
# Out:
# Please enter a phrase to title: hi
# Hi

# %%
# use a default argument
# This defines say_this() with a default argument of "Hi", then calls it with and without an argument
def say_this(phrase = "Hi"):
    """
    print the phrase entered

    args:
      phrase: string to be capitalized - defaults to Hi
    returns:
      none
    """

    print(phrase)

say_this()
say_this("Bye")
# Out:
# Hi
# Bye

# %% [markdown]
# ## Task 3:
#   - Define function `yell_this()` and call with variable argument
# - yell_this() should take the argument, make it all upper case and add an !
# - Define variable &nbsp; **`words_to_yell`** &nbsp; as a string gathered from user&nbsp; using the `input()` function
# - Call &nbsp;**`yell_this()`** &nbsp;with &nbsp; **`words_to_yell`** &nbsp;as argument
# - add appropriate documentation

# %%
# This defines yell_this(), which prints a phrase in caps with "!", then calls it with user input

def yell_this(phrase):
    """
    Print the phrase in upper-case letters followed by an exclamation point.

    args:
      phrase: string to be yelled

    returns:
      none
    """
    phrase = (phrase.upper() + "!")
    print(phrase)

words_to_yell = input("what would you like to yell? ")
yell_this(words_to_yell)
# Out:
# what would you like to yell? hello
# HELLO!

# %% [markdown]
# [Terms of use](http://go.microsoft.com/fwlink/?LinkID=206977) &nbsp; [Privacy & cookies](https://go.microsoft.com/fwlink/?LinkId=521839) &nbsp; © 2017 Microsoft
